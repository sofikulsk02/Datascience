# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("Olympics.csv")

# %%
data
# Out:
#     id                                name sex  age  height  weight  \
# 0    1                           A Dijiang   M   24   180.0    80.0
# 1    2                            A Lamusi   M   23   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M   24     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M   34     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F   21   185.0    82.0
# ..  ..                                 ...  ..  ...     ...     ...
# 95  32                Olav Augunson Aarnes   M   23     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M   24   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M   28   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M   30   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M   24   190.0    98.0
#
#               team  noc        games  year  season       city          sport  \
# 0            China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1            China  CHN  2012 Summer  2012  Summer     London           Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
# ..             ...  ...          ...   ...     ...        ...            ...
# 95          Norway  NOR  1912 Summer  1912  Summer  Stockholm      Athletics
# 96         Finland  FIN  1992 Summer  1992  Summer  Barcelona        Sailing
# 97         Finland  FIN  1996 Summer  1996  Summer    Atlanta        Sailing
# 98          France  FRA  2012 Summer  2012  Summer     London      Athletics
# 99          Norway  NOR  1998 Winter  1998  Winter     Nagano      Bobsleigh
#
#                                event medal
# 0        Basketball Men's Basketball   NaN
# 1       Judo Men's Extra-Lightweight   NaN
# 2            Football Men's Football   NaN
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 4   Speed Skating Women's 500 metres   NaN
# ..                               ...   ...
# 95         Athletics Men's High Jump   NaN
# 96   Sailing Men's Two Person Dinghy   NaN
# 97   Sailing Men's Two Person Dinghy   NaN
# 98    "Athletics Men's 1,500 metres"   NaN
# 99              Bobsleigh Men's Four   NaN
#
# [100 rows x 15 columns]

# %%
data.shape
# Out:
# (100, 15)

# %%
pd.crosstab(data.name,data.medal)
# Out:
# medal                      Bronze  Gold  Silver
# name
# Alf Lied Aanning                0     0       1
# Arvo Ossian Aaltonen            2     0       0
# Edgar Lindenau Aabye            0     1       0
# Juhamatti Tapio Aaltonen        1     0       0
# Kjetil Andr Aamodt              2     4       2
# Paavo Johannes Aaltonen         2     3       0
# Pepijn Aardewijn                0     0       1
# Ragnhild Margrethe Aamodt       0     1       0
# Willemien Aardenburg            1     0       0

# %%
data.name.nunique()
# Out:
# 35

# %%
pd.crosstab(data.name,data.medal=="Gold")
# Out:
# medal                                 False  True
# name
# A Dijiang                                 1      0
# A Lamusi                                  1      0
# Agnes Erika Aanonsen (-Eyde)              1      0
# Alf Lied Aanning                          1      0
# Andreea Aanei                             1      0
# Antti Sami Aalto                          1      0
# Arvo Ossian Aaltonen                      5      0
# Christine Jacoba Aaftink                  6      0
# Cornelia \Cor\" Aalten (-Strannood)"      2      0
# Dagfinn Sverre Aarskog                    1      0
# Edgar Lindenau Aabye                      0      1
# Einar Ferdinand \Einari\" Aalto"          1      0
# Evald rma (rman-)                         1      0
# Fritz Aanes                               2      0
# Gunnar Nielsen Aaby                       1      0
# Jamale (Djamel-) Aarrass (Ahrass-)        1      0
# Jan-Erik Aarberg                          2      0
# Johan Aantjes                             1      0
# John Aalberg                              8      0
# Jorma Ilmari Aalto                        1      0
# Juhamatti Tapio Aaltonen                  1      0
# Jyri Tapani Aalto                         1      0
# Kjetil Andr Aamodt                       16      4
# Mika Lauri Aarnikka                       2      0
# Minna Maarit Aalto                        2      0
# Nils Egil Aaness                          3      0
# Olav Augunson Aarnes                      1      0
# Paavo Johannes Aaltonen                  13      3
# Pepijn Aardewijn                          2      0
# Per Knut Aaland                           8      0
# Pirjo Hannele Aalto (Mattila-)            1      0
# Ragnhild Margrethe Aamodt                 0      1
# Timo Antero Aaltonen                      1      0
# Willemien Aardenburg                      1      0
# Win Valdemar Aaltonen                     1      0

# %%
data.columns
# Out:
# Index(['id', 'name', 'sex', 'age', 'height', 'weight', 'team', 'noc', 'games',
#        'year', 'season', 'city', 'sport', 'event', 'medal'],
#       dtype='object')

# %%
pd.crosstab(data.team,data.medal)
# Out:
# medal           Bronze  Gold  Silver
# team
# Denmark/Sweden       0     1       0
# Finland              5     3       0
# Netherlands          1     0       1
# Norway               2     5       3

# %%
athlete_medals = data.groupby('name').size()
most_medals_athlete = athlete_medals.idxmax()
most_medals_athlete
# Out:
# 'Kjetil Andr Aamodt'

# %%
freestyle_events = data[data['event'].str.contains('Freestyle')]
freestyle_events.event
# Out:
# 29    Swimming Men's 400 metres Freestyle
# Name: event, dtype: object

# %%
athlete_medals = data.groupby('name').size().sort_values(ascending=False).head(3)
athlete_medals
# Out:
# name
# Kjetil Andr Aamodt         20
# Paavo Johannes Aaltonen    16
# John Aalberg                8
# dtype: int64

# %%
a = data.groupby(['year', 'name']).size()
x = a[a > 1]
x
# Out:
# year  name
# 1912  Arvo Ossian Aaltonen                    2
# 1920  Arvo Ossian Aaltonen                    2
# 1932  Cornelia \Cor\" Aalten (-Strannood)"    2
# 1948  Paavo Johannes Aaltonen                 8
# 1952  Paavo Johannes Aaltonen                 8
# 1960  Nils Egil Aaness                        2
# 1988  Christine Jacoba Aaftink                2
# 1992  Christine Jacoba Aaftink                2
#       John Aalberg                            4
#       Kjetil Andr Aamodt                      4
#       Per Knut Aaland                         4
# 1994  Christine Jacoba Aaftink                2
#       John Aalberg                            4
#       Kjetil Andr Aamodt                      5
#       Per Knut Aaland                         4
# 1998  Kjetil Andr Aamodt                      4
# 2002  Kjetil Andr Aamodt                      5
# 2006  Kjetil Andr Aamodt                      2
# dtype: int64

# %%
x = data[data["medal"]=="Silver"]
x.name.unique()
# Out:
# array(['Kjetil Andr Aamodt', 'Alf Lied Aanning', 'Pepijn Aardewijn'],
#       dtype=object)

# %%
a = data.groupby(['medal']).size()
b= a[a>50]
b
# Out:
# Series([], dtype: int64)

# %%
a = data.groupby(['name','medal']).size()
a.aggregate
# Out:
# <bound method Series.aggregate of name                       medal
# Alf Lied Aanning           Silver    1
# Arvo Ossian Aaltonen       Bronze    2
# Edgar Lindenau Aabye       Gold      1
# Juhamatti Tapio Aaltonen   Bronze    1
# Kjetil Andr Aamodt         Bronze    2
#                            Gold      4
#                            Silver    2
# Paavo Johannes Aaltonen    Bronze    2
#                            Gold      3
# Pepijn Aardewijn           Silver    1
# Ragnhild Margrethe Aamodt  Gold      1
# Willemien Aardenburg       Bronze    1
# dtype: int64>

# %%
a = data.groupby(['team','sport']).size()
b = a.groupby(['team']).size()
c = b[b>10]
c
# Out:
# Series([], dtype: int64)
